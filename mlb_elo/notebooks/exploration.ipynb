# %%
import pandas as pd
import pybaseball
import statsapi

# %%
data = pybaseball.schedule_and_record(2021, "SFG")
# Out:
# http://www.baseball-reference.com/teams/SFG/2021-schedule-scores.shtml

# %%
games = statsapi.schedule(start_date='07/01/2022',end_date='07/31/2022')

# %%
game0 = statsapi.schedule(start_date='07/01/2023',end_date='07/02/2023')

# %%
[ (x['game_id'], x['game_date']) for x in game0]
#len(game0)
#game0[0]
# Out:
# [(717539, '2023-07-01'),
#  (717545, '2023-07-01'),
#  (717550, '2023-07-01'),
#  (717547, '2023-07-01'),
#  (717542, '2023-07-01'),
#  (717541, '2023-07-01'),
#  (717543, '2023-07-01'),
#  (717540, '2023-07-01'),
#  (717538, '2023-07-01'),
#  (717535, '2023-07-01'),
#  (717536, '2023-07-01'),
#  (717546, '2023-07-01'),
#  (717537, '2023-07-01'),
#  (717534, '2023-07-01'),
#  (717544, '2023-07-01'),
#  (717533, '2023-07-01'),
#  (717529, '2023-07-02'),
#  (717528, '2023-07-02'),
#  (717532, '2023-07-02'),
#  (717531, '2023-07-02'),
#  (717530, '2023-07-02'),
#  (717526, '2023-07-02'),
#  (717527, '2023-07-02'),
#  (717524, '2023-07-02'),
#  (717520, '2023-07-02'),
#  (717523, '2023-07-02'),
#  (717522, '2023-07-02'),
#  (717518, '2023-07-02'),
#  (717519, '2023-07-02'),
#  (717521, '2023-07-02'),
#  (717525, '2023-07-02')]

# %%
data['DateT'] = pd.to_datetime(data['Date'], format='%A, %b %d')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 data['DateT'] = pd.to_datetime(data['Date'], format='%A, %b %d')
#
# File ~/Library/Caches/pypoetry/virtualenvs/mlb-elo-1X5ZiPEl-py3.11/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:1050, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1048         result = arg.map(cache_array)
#    1049     else:
# -> 1050         values = convert_listlike(arg._values, format)
#    1051         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1052 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ...

# %%
data[27:32]
# Out:
#                   Date   Tm Home_Away  Opp   W/L     R   RA  Inn    W-L  Rank  \
# 28       Sunday, May 2  SFG         @  SDP     W   7.0  1.0  9.0  17-11   1.0
# 29  Tuesday, May 4 (1)  SFG         @  COL     W  12.0  4.0  7.0  18-11   1.0
# 30  Tuesday, May 4 (2)  SFG         @  COL  L-wo   6.0  8.0  7.0  18-12   1.0
# 31    Wednesday, May 5  SFG         @  COL     L   5.0  6.0  9.0  18-13   1.0
# 32       Friday, May 7  SFG      Home  SDP     W   5.0  4.0  9.0  19-13   1.0
#
#         GB      Win      Loss   Save  Time D/N  Attendance   cLI  Streak  \
# 28  up 0.5  Gausman  Musgrove   None  3:10   D     15250.0  1.39       1
# 29  up 1.5   Wisler   Márquez   None  2:38   D         NaN  1.24       2
# 30  up 1.5   Bowden     Doval   None  3:04   N     10213.0  1.25      -1
# 31  up 0.5     Gray      Webb   Bard  3:08   D      9521.0  1.30      -2
# 32  up 1.5    Doval      Kela  McGee  3:34   N      9219.0  1.46       1
#
#    Orig. Scheduled
# 28            None
# ...

# %%
data.sample(n=10)
# Out:
#                  Date   Tm Home_Away  Opp   W/L     R   RA   Inn    W-L  Rank  \
# 1    Thursday, Mar 30  NYY      Home  SFG     W   5.0  0.0   9.0    1-0   1.0
# 53     Friday, May 26  NYY      Home  SDP     L   1.0  5.0   9.0  30-23   3.0
# 57    Tuesday, May 30  NYY         @  SEA     W  10.0  2.0   9.0  34-23   3.0
# 22     Sunday, Apr 23  NYY      Home  TOR     L   1.0  5.0   9.0   13-9   3.0
# 105    Sunday, Jul 30  NYY         @  BAL  None   NaN  NaN   NaN   None   NaN
# 8     Saturday, Apr 8  NYY         @  BAL     W   4.0  1.0   9.0    5-3   2.0
# 148    Friday, Sep 15  NYY         @  PIT  None   NaN  NaN   NaN   None   NaN
# 130    Sunday, Aug 27  NYY         @  TBR  None   NaN  NaN   NaN   None   NaN
# 50    Tuesday, May 23  NYY      Home  BAL  W-wo   6.0  5.0  10.0  30-20   3.0
# 39   Thursday, May 11  NYY      Home  TBR     L   2.0  8.0   9.0  21-18   5.0
#
#      ...        Win     Loss    Save  Time   D/N Attendance   cLI Streak  \
# ...

# %%
teams = pybaseball.team_ids(2019)

# %%
x = statsapi.get('teams', {'sportIds':1,'activeStatus':'Yes'})

# %%
len(games)
gamesD = pd.DataFrame.from_dict(games)

# %%
pd.set_option('display.max_columns', 50)
gamesD
# Out:
#      game_id         game_datetime   game_date game_type status  \
# 0     663185  2022-07-01T18:20:00Z  2022-07-01         R  Final
# 1     661725  2022-07-01T19:07:00Z  2022-07-01         R  Final
# 2     661582  2022-07-01T22:05:00Z  2022-07-01         R  Final
# 3     662492  2022-07-01T22:05:00Z  2022-07-01         R  Final
# 4     663038  2022-07-01T22:40:00Z  2022-07-01         R  Final
# ..       ...                   ...         ...       ...    ...
# 391   661388  2022-07-31T18:10:00Z  2022-07-31         R  Final
# 392   662988  2022-07-31T19:10:00Z  2022-07-31         R  Final
# 393   663377  2022-07-31T20:07:00Z  2022-07-31         R  Final
# 394   662267  2022-07-31T20:10:00Z  2022-07-31         R  Final
# 395   662071  2022-07-31T23:08:00Z  2022-07-31         R  Final
#
#                away_name              home_name  away_id  home_id  \
# 0         Boston Red Sox           Chicago Cubs      111      112
# ...

# %%
gamesD.status.value_counts()
data.sample(n=10)
# Out:
#                   Date   Tm Home_Away  Opp   W/L    R   RA  Inn    W-L  Rank  \
# 122     Friday, Aug 20  SFG         @  OAK     L  1.0  4.0  9.0  78-44   1.0
# 96    Thursday, Jul 22  SFG         @  LAD     W  5.0  3.0  9.0  61-35   1.0
# 119     Monday, Aug 16  SFG      Home  NYM     W  7.0  5.0  9.0  77-42   1.0
# 83       Sunday, Jul 4  SFG         @  ARI     W  5.0  2.0  9.0  53-30   1.0
# 118     Sunday, Aug 15  SFG      Home  COL     W  5.0  2.0  9.0  76-42   1.0
# 126  Wednesday, Aug 25  SFG         @  NYM     W  3.0  2.0  9.0  82-44   1.0
# 59       Sunday, Jun 6  SFG      Home  CHC     L  3.0  4.0  9.0  37-22   1.0
# 127   Thursday, Aug 26  SFG         @  NYM     W  3.0  2.0  9.0  83-44   1.0
# 67     Tuesday, Jun 15  SFG      Home  ARI     W  9.0  8.0  9.0  42-25   1.0
# 18   Wednesday, Apr 21  SFG         @  PHI  L-wo  5.0  6.0  9.0   11-7   2.0
#
#          GB         Win         Loss     Save  Time D/N  Attendance   cLI  \
# ...

# %%
statsapi.lookup_team('OAK', season=2000)
x
# Out:
# {'copyright': 'Copyright 2023 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt',
#  'teams': [{'springLeague': {'id': 114,
#     'name': 'Cactus League',
#     'link': '/api/v1/league/114',
#     'abbreviation': 'CL'},
#    'allStarStatus': 'N',
#    'id': 133,
#    'name': 'Oakland Athletics',
#    'link': '/api/v1/teams/133',
#    'season': 2023,
#    'venue': {'id': 10,
#     'name': 'Oakland Coliseum',
#     'link': '/api/v1/venues/10'},
#    'springVenue': {'id': 2507, 'link': '/api/v1/venues/2507'},
#    'teamCode': 'oak',
#    'fileCode': 'oak',
#    'abbreviation': 'OAK',
#    'teamName': 'Athletics',
#    'locationName': 'Oakland',
#    'firstYearOfPlay': '1901',
#    'league': {'id': 103,
#     'name': 'American League',
#     'link': '/api/v1/league/103'},
#    'division': {'id': 200,
#     'name': 'American League West',
#     'link': '/api/v1/divisions/200'},
# ...
