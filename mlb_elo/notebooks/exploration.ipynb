# %%
import pybaseball

# %%
data = pybaseball.schedule_and_record(2023, "NYY")
# Out:
# http://www.baseball-reference.com/teams/NYY/2023-schedule-scores.shtml

# %%
data.query('`W/L` in ("L","W")')
# Out:
#                 Date   Tm Home_Away  Opp W/L    R    RA  Inn    W-L  Rank  \
# 1   Thursday, Mar 30  NYY      Home  SFG   W  5.0   0.0  9.0    1-0   1.0
# 2    Saturday, Apr 1  NYY      Home  SFG   L  5.0   7.0  9.0    1-1   2.0
# 3      Sunday, Apr 2  NYY      Home  SFG   W  6.0   0.0  9.0    2-1   2.0
# 4      Monday, Apr 3  NYY      Home  PHI   W  8.0   1.0  9.0    3-1   2.0
# 5     Tuesday, Apr 4  NYY      Home  PHI   L  1.0   4.0  9.0    3-2   2.0
# ..               ...  ...       ...  ...  ..  ...   ...  ...    ...   ...
# 87  Wednesday, Jul 5  NYY      Home  BAL   L  3.0   6.0  9.0  48-39   3.0
# 88   Thursday, Jul 6  NYY      Home  BAL   L  1.0  14.0  9.0  48-40   3.0
# 89     Friday, Jul 7  NYY      Home  CHC   L  0.0   3.0  9.0  48-41   4.0
# 90   Saturday, Jul 8  NYY      Home  CHC   W  6.0   3.0  9.0  49-41   3.0
# 91     Sunday, Jul 9  NYY      Home  CHC   L  4.0   7.0  9.0  49-42   4.0
#
#       GB           Win        Loss      Save  Time D/N  Attendance   cLI  \
# ...
